# %%
from __future__ import division
# %pylab --no-import-all
# %matplotlib inline
import pandas as pd
# Out:
# Using matplotlib backend: MacOSX
# Populating the interactive namespace from numpy and matplotlib

# %%
df=pd.read_excel('http://www.rug.nl/research/ggdc/data/pwt/v80/pwt80.xlsx',sheetname=1)
dfpwt=pd.read_excel('http://www.rug.nl/research/ggdc/data/pwt/v80/pwt80.xlsx',sheetname=2)

# %%
df
# Out:
#                                        Variable name  \
# 0                               Identifier variables
# 1                                        countrycode
# 2                                            country
# 3                                      currency_unit
# 4                                               year
# 5                                                NaN
# 6         Real GDP, employment and population levels
# 7                                              rgdpe
# 8                                              rgdpo
# 9                                                pop
# 10                                               emp
# 11                                               avh
# 12                                                hc
# 13                                               NaN
# 14                Current price GDP, capital and TFP
# 15                                             cgdpe
# 16                                             cgdpo
# 17                                                ck
# 18                                              ctfp
# 19                                               NaN
# 20                 National accounts-based variables
# 21                                            rgdpna
# 22                                              rkna
# 23                                            rtfpna
# 24                                             labsh
# 25                                               NaN
# 26               Exchange rates and GDP price levels
# 27                                                xr
# 28                                           pl_gdpe
# 29                                           pl_gdpo
# 30                                               NaN
# 31                        Data information variables
# 32                                             i_cig
# 33                                              i_xm
# 34                                              i_xr
# 35                                         i_outlier
# 36                                           cor_exp
# 37                                           statcap
# 38                                               NaN
# 39                                   Shares in CGDPo
# 40                                             csh_c
# 41                                             csh_i
# 42                                             csh_g
# 43                                             csh_x
# 44                                             csh_m
# 45                                             csh_r
# 46                                               NaN
# 47  Price levels, expenditure categories and capital
# 48                                              pl_c
# 49                                              pl_i
# 50                                              pl_g
# 51                                              pl_x
# 52                                              pl_m
# 53                                              pl_k
#
#                                   Variable definition
# 0                                                 NaN
# 1                           3-letter ISO country code
# 2                                        Country name
# 3                                       Currency unit
# 4                                                Year
# 5                                                 NaN
# 6                                                 NaN
# 7   Expenditure-side real GDP at chained PPPs (in ...
# 8   Output-side real GDP at chained PPPs (in mil. ...
# 9                            Population (in millions)
# 10            Number of persons engaged (in millions)
# 11     Average annual hours worked by persons engaged
# 12  Index of human capital per person, based on ye...
# 13                                                NaN
# 14                                                NaN
# 15  Expenditure-side real GDP at current PPPs (in ...
# 16  Output-side real GDP at current PPPs (in mil. ...
# 17    Capital stock at current PPPs (in mil. 2005US$)
# 18                  TFP level at current PPPs (USA=1)
# 19                                                NaN
# 20                                                NaN
# 21  Real GDP at constant 2005 national prices (in ...
# 22  Capital stock at constant 2005 national prices...
# 23           TFP at constant national prices (2005=1)
# 24  Share of labour compensation in GDP at current...
# 25                                                NaN
# 26                                                NaN
# 27  Exchange rate, national currency/USD (market+e...
# 28  Price level of CGDPe (PPP/XR), price level of ...
# 29  Price level of CGDPo (PPP/XR),  price level of...
# 30                                                NaN
# 31                                                NaN
# 32  0/1/2: relative price data for consumption, in...
# 33  0/1/2: relative price data for exports and imp...
# 34  0/1: the exchange rate is market-based (0) or ...
# 35  0/1: the observation on pl_gdpe or pl_gdpo is ...
# 36  Correlation between expenditure shares of the ...
# 37  Statistical capacity indicator (source: World ...
# 38                                                NaN
# 39                                                NaN
# 40     Share of household consumption at current PPPs
# 41   Share of gross capital formation at current PPPs
# 42    Share of government consumption at current PPPs
# 43       Share of merchandise exports at current PPPs
# 44       Share of merchandise imports at current PPPs
# 45  Share of residual trade and GDP statistical di...
# 46                                                NaN
# 47                                                NaN
# 48  Price level of household consumption,  price l...
# 49  Price level of capital formation,  price level...
# 50  Price level of government consumption,  price ...
# 51  Price level of exports, price level of USA GDP...
# 52  Price level of imports, price level of USA GDP...
# 53  Price level of the capital stock, price level ...
